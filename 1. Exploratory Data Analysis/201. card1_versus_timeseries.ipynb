# %% [markdown]
# ### 작성일 : 19/08/01
# ### 목적 : card1 변수의 시간별 분포 특징을 파악

# %%
library(data.table)
library(ggplot2)
library(dplyr)
options(repr.plot.width = 5, repr.plot.height = 3)
options(scipen = 100)
library(ggpubr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Loading required package: magrittr

# %%
tr <- fread("/Users/jeong/downloads/IEEE/input/train_transaction.csv")
te <- fread("/Users/jeong/downloads/IEEE/input/test_transaction.csv")

tr_id <- fread("/Users/jeong/downloads/IEEE/input/train_identity.csv")
te_id <- fread("/Users/jeong/downloads/IEEE/input/test_identity.csv")

# %%
card1_top <- tr[, .N, by= card1]
card1_top = card1_top[order(-N)]
head(card1_top)
# Out:
#   card1 N
# 1  7919 14932
# 2  9500 14162
# 3 15885 10361
# 4 17188 10344
# 5 15066  7945
# 6 12695  7091

# %%
card1_top$card1[1]
# Out:
# [1] 7919

# %%
cat("card1 :  ", card1_top$card1[1], "\n")
cat(round(nrow(tr[card1 == card1_top$card1[1]]) / nrow(tr)*100,1), "%")
a1 <- ggplot(tr[card1 == card1_top$card1[1]], aes(TransactionDT, fill = factor(isFraud))) + 
    geom_histogram(alpha= 0.7, bins = 100 )
b1 <- ggplot(tr[card1 == card1_top$card1[1]], aes(TransactionDT, fill = factor(isFraud))) + 
    geom_histogram(alpha= 0.7, position = 'fill', bins = 100) + coord_cartesian( ylim = c(0, 0.2)) 


options(repr.plot.width = 20, repr.plot.height = 12)
figure <- ggarrange(a1, b1,
                    common.legend = TRUE, legend = "bottom",
                    nrow = 2, ncol = 1)
figure
# Out:
# card1 :   7919
# 2.5 %
# plot without title

# %%
cat("card1 :  ", card1_top$card1[2], "\n")
cat(round(nrow(tr[card1 == card1_top$card1[2]]) / nrow(tr)*100,1), "%")
a1 <- ggplot(tr[card1 == card1_top$card1[2]], aes(TransactionDT, fill = factor(isFraud))) + 
    geom_histogram(alpha= 0.7, bins = 100 )
b1 <- ggplot(tr[card1 == card1_top$card1[2]], aes(TransactionDT, fill = factor(isFraud))) + 
    geom_histogram(alpha= 0.7, position = 'fill', bins = 100) + coord_cartesian( ylim = c(0, 0.2)) 


options(repr.plot.width = 20, repr.plot.height = 12)
figure <- ggarrange(a1, b1,
                    common.legend = TRUE, legend = "bottom",
                    nrow = 2, ncol = 1)
figure
# Out:
# card1 :   9500
# 2.4 %
# plot without title

# %%
cat("card1 :  ", card1_top$card1[3], "\n")
cat(round(nrow(tr[card1 == card1_top$card1[3]]) / nrow(tr)*100,1), "%")
a1 <- ggplot(tr[card1 == card1_top$card1[3]], aes(TransactionDT, fill = factor(isFraud))) + 
    geom_histogram(alpha= 0.7, bins = 100 )
b1 <- ggplot(tr[card1 == card1_top$card1[3]], aes(TransactionDT, fill = factor(isFraud))) + 
    geom_histogram(alpha= 0.7, position = 'fill', bins = 100) + coord_cartesian( ylim = c(0, 0.2)) 


options(repr.plot.width = 20, repr.plot.height = 12)
figure <- ggarrange(a1, b1,
                    common.legend = TRUE, legend = "bottom",
                    nrow = 2, ncol = 1)
figure
# Out:
# card1 :   15885
# 1.8 %
# plot without title

# %%
cat("card1 :  ", card1_top$card1[4], "\n")
cat(round(nrow(tr[card1 == card1_top$card1[4]]) / nrow(tr)*100,1), "%")
a1 <- ggplot(tr[card1 == card1_top$card1[4]], aes(TransactionDT, fill = factor(isFraud))) + 
    geom_histogram(alpha= 0.7, bins = 100 )
b1 <- ggplot(tr[card1 == card1_top$card1[4]], aes(TransactionDT, fill = factor(isFraud))) + 
    geom_histogram(alpha= 0.7, position = 'fill', bins = 100) + coord_cartesian( ylim = c(0, 0.2)) 


options(repr.plot.width = 20, repr.plot.height = 12)
figure <- ggarrange(a1, b1,
                    common.legend = TRUE, legend = "bottom",
                    nrow = 2, ncol = 1)
figure
# Out:
# card1 :   17188
# 1.8 %
# plot without title

# %%
cat("card1 :  ", card1_top$card1[5], "\n")
cat(round(nrow(tr[card1 == card1_top$card1[5]]) / nrow(tr)*100,1), "%")
a1 <- ggplot(tr[card1 == card1_top$card1[5]], aes(TransactionDT, fill = factor(isFraud))) + 
    geom_histogram(alpha= 0.7, bins = 100 )
b1 <- ggplot(tr[card1 == card1_top$card1[5]], aes(TransactionDT, fill = factor(isFraud))) + 
    geom_histogram(alpha= 0.7, position = 'fill', bins = 100) + coord_cartesian( ylim = c(0, 0.2)) 


options(repr.plot.width = 20, repr.plot.height = 12)
figure <- ggarrange(a1, b1,
                    common.legend = TRUE, legend = "bottom",
                    nrow = 2, ncol = 1)
figure
# Out:
# card1 :   15066
# 1.3 %
# plot without title

# %% [markdown]
# - transaction count와 fraud_ratiosms 반비례한다?
